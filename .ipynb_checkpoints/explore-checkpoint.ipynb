# %%
import glob

meta = glob.glob('meta/*.csv')
meta
# Out:
# ['meta/excluded_or_corrected.csv',
#  'meta/metadata_manual_adds.csv',
#  'meta/metadata_nulls_not_removed.csv',
#  'meta/metadata_fuzzy_matches_gutenberg_pre_1850.csv',
#  'meta/metadata_genre_fuzzy_matches.csv',
#  'meta/metadata_no_null.csv',
#  'meta/finalmeta_hand_edited.csv',
#  'meta/underwood_genre_with_zscores.csv',
#  'meta/metadata_missing_some_viaf.csv',
#  'meta/finalmeta.csv',
#  'meta/metadata_underwood_joined.csv',
#  'meta/metadata_fuzzy_matches_gutenberg.csv',
#  'meta/gutenberg_post_1860_fiction_authors_deletions.csv',
#  'meta/df_extra_culled.csv',
#  'meta/gutenberg_post_1860_fiction_authors.csv',
#  'meta/metadata_fuzzy_matches_gutenberg_hand_edited.csv']

# %%
import pandas as pd
for i in meta:
    df = pd.read_csv(i, encoding='latin-1')
    print(i, len(df))
# Out:
# meta/excluded_or_corrected.csv 10
# meta/metadata_manual_adds.csv 179
# meta/metadata_nulls_not_removed.csv 633
# meta/metadata_fuzzy_matches_gutenberg_pre_1850.csv 448
# meta/metadata_genre_fuzzy_matches.csv 977
# meta/metadata_no_null.csv 264
# meta/finalmeta_hand_edited.csv 984
# meta/underwood_genre_with_zscores.csv 962
# meta/metadata_missing_some_viaf.csv 638
# meta/finalmeta.csv 1347
# meta/metadata_underwood_joined.csv 1168
# meta/metadata_fuzzy_matches_gutenberg.csv 138
# meta/gutenberg_post_1860_fiction_authors_deletions.csv 4150
# meta/df_extra_culled.csv 165
# meta/gutenberg_post_1860_fiction_authors.csv 4728
# meta/metadata_fuzzy_matches_gutenberg_hand_edited.csv 139

# %%
df = pd.read_csv('meta/finalmeta.csv', encoding='latin-1', index_col=0)
df.loc[~df['gutenberg_id'].isna()].sort_values(by='gutenberg_id').sort_values(by='date')
# Out:
#                               date                                  genre  \
# author
# Defoe, Daniel, 1661?-1731     1706                                    fic
# Congreve, William, 1670-1729  1713                                    fic
# Defoe, Daniel, 1661?-1731     1719                                    fic
# Defoe, Daniel, 1661?-1731     1719                                    fic
# Defoe, Daniel, 1661?-1731     1721                                    fic
# ...                            ...                                    ...
# Hillerman, Tony,              1989                      teamred | chimyst
# Dunlap, Susan,                1989   chirandom | teamred | chimyst | stew
# Crais, Robert,                1989                      teamred | chimyst
# McMurtry, Larry,              1989                  chirandom | teamblack
# Cook, Robin,                  1989  teamred | chihorror | chiscifi | stew
#
#                              gutenberg_id        source  \
# author
# ...

# %%
df.loc[(df['genre'] == 'fic' ) & (df['source'] == 'gutenberg')].groupby('date').count().reset_index().plot.bar(x='date', y='genre')
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df.loc[(df['genre'] == 'fic' ) & (df['source'] == 'gutenberg')].groupby('date').count().sort_values(by='genre', ascending=False).head(50)
# Out:
#       genre  gutenberg_id  source  title  viaf_author_uri
# date
# 1920     16            16      16     16                0
# 1922     13            13      13     13                0
# 1914     10            10      10     10                0
# 1921     10            10      10     10                0
# 1915     10            10      10     10                0
# 1918      9             9       9      9                0
# 1912      9             9       9      9                0
# 1916      8             8       8      8                0
# 1908      7             7       7      7                0
# 1911      7             7       7      7                0
# 1909      6             6       6      6                0
# 1886      6             6       6      6                6
# 1910      6             6       6      6                0
# 1858      6             6       6      6                6
# 1818      6             6       6      6                6
# ...

# %%
df.loc[df['source'] == 'lavin']
# Out:
#                date genre                 gutenberg_id source  \
# author
# Cather, Willa  1912   fic  alexanders_bridge_processed  lavin
# Cather, Willa  1913   fic         o_pioneers_processed  lavin
# Cather, Willa  1915   fic          song_lark_processed  lavin
# Cather, Willa  1918   fic            antonia_processed  lavin
# Cather, Willa  1922   fic        one_of_ours_processed  lavin
# Cather, Willa  1923   fic          lost_lady_processed  lavin
# Cather, Willa  1925   fic         prof_house_processed  lavin
# Cather, Willa  1927   fic        death_comes_processed  lavin
# Cather, Willa  1935   fic      lucy_gayheart_processed  lavin
# Cather, Willa  1931   fic       shadows_rock_processed  lavin
# Cather, Willa  1940   fic           sapphira_processed  lavin
#
#                                         title               viaf_author_uri
# author
# Cather, Willa              Alexander's Bridge  http://viaf.org/viaf/2480701
# ...

# %%
full_text = glob.glob('txts/gutenberg_full_text/*.txt')

# %%
these_ids = []
for i in full_text:
    ids = ";".join(i.split('/')[-1].split('.')[0].split('_'))
    these_ids.append(ids)

# %%
for i in meta:
    df = pd.read_csv(i, encoding='latin-1')
    try:
        print(i, len(df.loc[df['gutenberg_id'].isin(these_ids)]))
    except:
        pass
# Out:
# meta/metadata_manual_adds.csv 158
# meta/metadata_nulls_not_removed.csv 227
# meta/metadata_no_null.csv 227
# meta/metadata_missing_some_viaf.csv 128
# meta/finalmeta.csv 388
# meta/metadata_underwood_joined.csv 230
# meta/gutenberg_post_1860_fiction_authors_deletions.csv 0
# meta/df_extra_culled.csv 0
# meta/gutenberg_post_1860_fiction_authors.csv 0

# %%
df_cather = df.loc[df['source'] == 'lavin']

# %%
def make_path(row):
    gutenberg_id = row['gutenberg_id']
    this_path = f'txts/other_tsv/{gutenberg_id}.tsv'
    return this_path
df_cather['filepath'] = df_cather.apply(make_path, axis=1)
df_cather
# Out:
#                date genre                 gutenberg_id source  \
# author
# Cather, Willa  1912   fic  alexanders_bridge_processed  lavin
# Cather, Willa  1913   fic         o_pioneers_processed  lavin
# Cather, Willa  1915   fic          song_lark_processed  lavin
# Cather, Willa  1918   fic            antonia_processed  lavin
# Cather, Willa  1922   fic        one_of_ours_processed  lavin
# Cather, Willa  1923   fic          lost_lady_processed  lavin
# Cather, Willa  1925   fic         prof_house_processed  lavin
# Cather, Willa  1927   fic        death_comes_processed  lavin
# Cather, Willa  1935   fic      lucy_gayheart_processed  lavin
# Cather, Willa  1931   fic       shadows_rock_processed  lavin
# Cather, Willa  1940   fic           sapphira_processed  lavin
#
#                                         title               viaf_author_uri  \
# author
# Cather, Willa              Alexander's Bridge  http://viaf.org/viaf/2480701
# ...

# %%
full_text = []
for e, row in df_cather.iterrows():
    df = pd.read_csv(row['filepath'], sep='\t', header=None)
    df.columns = ['word', 'count']
    df['source'] = row['gutenberg_id']
    full_text.append(df)

# %%
novel_text_joined = pd.concat(full_text)

# %%
novel_text_joined.loc[novel_text_joined['word'] == 'twilight']
# Out:
#           word  count                       source
# 2281  twilight      1  alexanders_bridge_processed
# 2561  twilight      2         o_pioneers_processed
# 1999  twilight      6          song_lark_processed
# 3397  twilight      2            antonia_processed
# 2164  twilight      5        one_of_ours_processed
# 2869  twilight      3          lost_lady_processed
# 2467  twilight      2         prof_house_processed
# 2626  twilight      3        death_comes_processed
# 2150  twilight      2      lucy_gayheart_processed
# 1801  twilight      3       shadows_rock_processed
# 1614  twilight      3           sapphira_processed

# %%
# archbishop 
'''
The Bishop sat a long time by the spring, while the declining sun poured
its beautifying light over those low, rose-tinted houses and bright
gardens. The old grandfather had shown him arrow-heads and corroded
medals, and a sword hilt, evidently Spanish, that he had found in the
earth near the water-head. This spot had been a refuge for humanity long
before these Mexicans had come upon it. It was older than history, like
those well-heads in his own country where the Roman settlers had set up
the image of a river goddess, and later the Christian priests had
planted a cross. This settlement was his Bishopric in miniature;
hundreds of square miles of thirsty desert, then a spring, a village,
old men trying to remember their catechism to teach their grandchildren.
The Faith planted by the Spanish friars and watered with their blood was
not dead; it awaited only the toil of the husbandman. He was not
troubled about the revolt in Santa Fé, or the powerful old native
priest who led it--Father Martinez, of Taos, who had ridden over from
his parish expressly to receive the new Vicar and to drive him away. He
was rather terrifying, that old priest, with his big head, violent
Spanish face, and shoulders like a buffalo; but the day of his tyranny
was almost over.
'''
# o pioneers
'''
They were grown men now, and, as Alexandra said, for the last few years they 
had been growing more and more like themselves. Lou was still the slighter of 
the two, the quicker and more intelligent, but apt to go off at half-cock. He 
had a lively blue eye, a thin, fair skin (always burned red to the neckband of 
his shirt in summer), stiff, yellow hair that would not lie down on his head, 
and a bristly little yellow mustache, of which he was very proud. Oscar could 
not grow a mustache; his pale face was as bare as an egg, and his white eyebrows 
gave it an empty look. He was a man of powerful body and unusual endurance; the 
sort of man you could attach to a corn-sheller as you would an engine. He would 
turn it all day, without hurrying, without slowing down. But he was as indolent 
of mind as he was unsparing of his body. His love of routine amounted to a vice. 
He worked like an insect, always doing the same thing over in the same way, 
regardless of whether it was best or no. He felt that there was a sovereign 
virtue in mere bodily toil, and he rather liked to do things in the hardest way. 
If a field had once been in corn, he couldn’t bear to put it into wheat. He liked 
to begin his corn-planting at the same time every year, whether the season were 
backward or forward. He seemed to feel that by his own irreproachable regularity 
he would clear himself of blame and reprove the weather. When the wheat crop 
failed, he threshed the straw at a dead loss to demonstrate how little grain 
there was, and thus prove his case against Providence.

Lou, on the other hand, was fussy and flighty; always planned to get through two 
days’ work in one, and often got only the least important things done. He liked 
to keep the place up, but he never got round to doing odd jobs until he had to 
neglect more pressing work to attend to them. In the middle of the wheat harvest, 
when the grain was over-ripe and every hand was needed, he would stop to mend 
fences or to patch the harness; then dash down to the field and overwork and be 
laid up in bed for a week. The two boys balanced each other, and they pulled well 
together. They had been good friends since they were children. One seldom went 
